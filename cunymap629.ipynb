# %%
from IPython.display import HTML
import folium

# %%
def inline_map(map):
    """
    Embeds the HTML source of the map directly into the IPython notebook.
    
    This method will not work if the map depends on any files (json data). Also this uses
    the HTML5 srcdoc attribute, which may not be supported in all browsers.
    """
    map._build_map()
    return HTML('<iframe srcdoc="{srcdoc}" style="width: 100%; height: 510px; border: none"></iframe>'.format(srcdoc=map.HTML.replace('"', '&quot;')))

def embed_map(map, path="map.html"):
    """
    Embeds a linked iframe to the map into the IPython notebook.
    
    Note: this method will not capture the source of the map into the notebook.
    This method should work for all maps (as long as they use relative urls).
    """
    map.create_map(path=path)
    return HTML('<iframe src="files/{path}" style="width: 100%; height: 510px; border: none"></iframe>'.format(path=path))

# %%
map = folium.Map(location=[40, -99], zoom_start=4)
map.circle_marker([40.737130, -74.026267], radius=500, popup='Hoboken, Sweet Hoboken.', line_color='3186cc', fill_color='31866cc', fill_opacity=0.2)
inline_map(map)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <link rel=&quot;stylesheet&quot; href=&quot;http://cdn.leafletjs.com/leaflet-0.5/leaflet.css&quot; />
#    <script src=&quot;http://cdn.leafletjs.com/leaflet-0.5/leaflet.js&quot;></script>
#
#
#
#
#
#
# <style>
#
# #map {
#   position:absolute;
#   top:0;
#   bottom:0;
#   right:0;
#   left:0;
# }
#
# </style>
# </head>
# <body>
#
#         <div id=&quot;map&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
# <script>
#
#
#
# var map = L.map('map').setView([40, -99], 4);
#
# L.tileLayer('http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#     maxZoom: 18,
#     attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
# }).addTo(map);
#
#
# var circle_1 = L.circle([40.73713, -74.026267], 500, {
#                             color: '3186cc',
#                             fillColor: '31866cc',
#                             fillOpacity: 0.2
#                             });
# circle_1.bindPopup(&quot;Hoboken, Sweet Hoboken.&quot;);
# map.addLayer(circle_1)
#
#
#
#
#
#
# </script>
#
# </body>" style="width: 100%; height: 510px; border: none"></iframe>

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/tjd/Documents/Cuny/geodata/cuny.csv')

# %%
df.head()
# Out:
#    id       lat       lon  fakename gender  gradetotal  fakeage  income  \
# 0   1  40.24104 -74.27629   Geraldo      m         154       29   22000
# 1   2  40.35589 -86.88972   Ophelia      f         143       41   80000
# 2   3  40.77610 -73.98285  Valencia      f         327       52    5000
# 3   4  43.04117 -86.19013    Cezary      m         307       56  185000
# 4   5  40.74946 -73.81941  Alphonse      m         283       38  146381
#
#    twitter
# 0     4699
# 1     4360
# 2     4734
# 3     7550
# 4     4961
#
# [5 rows x 9 columns]

# %%
cuny_map = folium.Map(location=[40.737130, -74.026267], zoom_start=12, 
                        tiles='Stamen Terrain')
cuny_map.lat_lng_popover()
for row in df.iterrows():
    wtg_id = str(row[1]['fakename'])
    lat = row[1]['lat']
    lng = row[1]['lon']
    cuny_map.polygon_marker(location=[lat, lng], fill_color='#f4bf75', 
                              radius=12, num_sides=6, popup='Name: ' + wtg_id)
cuny_map.create_map('cuny_map.html')
cuny_map.render_iframe = True
cuny_map

# %%
map = cuny_map
inline_map(map)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <link rel=&quot;stylesheet&quot; href=&quot;http://cdn.leafletjs.com/leaflet-0.5/leaflet.css&quot; />
#    <script src=&quot;http://cdn.leafletjs.com/leaflet-0.5/leaflet.js&quot;></script>
#    <script src=&quot;leaflet-dvf.markers.min.js&quot;></script>
#
#
#
#
#
# <style>
#
# #map {
#   position:absolute;
#   top:0;
#   bottom:0;
#   right:0;
#   left:0;
# }
#
# </style>
# </head>
# <body>
#
#         <div id=&quot;map&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
# <script>
#
#
#
# var map = L.map('map').setView([40.73713, -74.026267], 12);
#
# L.tileLayer('http://{s}.tile.stamen.com/terrain/{z}/{x}/{y}.jpg', {
#     maxZoom: 18,
#     attribution: 'Map tiles by <a href=&quot;http://stamen.com&quot;>Stamen Design</a>, under <a href=&quot;http://creativecommons.org/licenses/by/3.0&quot;>CC BY 3.0</a>. Data by <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a>, under <a href=&quot;http://creativecommons.org/licenses/by-sa/3.0&quot;>CC BY SA</a>.'
# }).addTo(map);
#
#
# var polygon_1 = new L.RegularPolygonMarker(new L.LatLng(40.24104, -74.27629), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_1._latlng = polygon_1._centerLatLng
# polygon_1.bindPopup(&quot;Name: Geraldo&quot;);
# map.addLayer(polygon_1)
#
# var polygon_2 = new L.RegularPolygonMarker(new L.LatLng(40.35589, -86.88972), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_2._latlng = polygon_2._centerLatLng
# polygon_2.bindPopup(&quot;Name: Ophelia&quot;);
# map.addLayer(polygon_2)
#
# var polygon_3 = new L.RegularPolygonMarker(new L.LatLng(40.7761, -73.98285), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_3._latlng = polygon_3._centerLatLng
# polygon_3.bindPopup(&quot;Name: Valencia&quot;);
# map.addLayer(polygon_3)
#
# var polygon_4 = new L.RegularPolygonMarker(new L.LatLng(43.04117, -86.19013), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_4._latlng = polygon_4._centerLatLng
# polygon_4.bindPopup(&quot;Name: Cezary&quot;);
# map.addLayer(polygon_4)
#
# var polygon_5 = new L.RegularPolygonMarker(new L.LatLng(40.74946, -73.81941), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_5._latlng = polygon_5._centerLatLng
# polygon_5.bindPopup(&quot;Name: Alphonse&quot;);
# map.addLayer(polygon_5)
#
# var polygon_6 = new L.RegularPolygonMarker(new L.LatLng(38.07655, -78.89839), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_6._latlng = polygon_6._centerLatLng
# polygon_6.bindPopup(&quot;Name: Sabriel&quot;);
# map.addLayer(polygon_6)
#
# var polygon_7 = new L.RegularPolygonMarker(new L.LatLng(38.99976, -77.10185), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_7._latlng = polygon_7._centerLatLng
# polygon_7.bindPopup(&quot;Name: Elizabeth&quot;);
# map.addLayer(polygon_7)
#
# var polygon_8 = new L.RegularPolygonMarker(new L.LatLng(40.71209, -73.95427), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_8._latlng = polygon_8._centerLatLng
# polygon_8.bindPopup(&quot;Name: William&quot;);
# map.addLayer(polygon_8)
#
# var polygon_9 = new L.RegularPolygonMarker(new L.LatLng(40.82892, -74.11064), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_9._latlng = polygon_9._centerLatLng
# polygon_9.bindPopup(&quot;Name: Arnold&quot;);
# map.addLayer(polygon_9)
#
# var polygon_10 = new L.RegularPolygonMarker(new L.LatLng(40.99208, -73.8729), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_10._latlng = polygon_10._centerLatLng
# polygon_10.bindPopup(&quot;Name: Madeline&quot;);
# map.addLayer(polygon_10)
#
# var polygon_11 = new L.RegularPolygonMarker(new L.LatLng(41.29687, -73.78934), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_11._latlng = polygon_11._centerLatLng
# polygon_11.bindPopup(&quot;Name: Hemione&quot;);
# map.addLayer(polygon_11)
#
# var polygon_12 = new L.RegularPolygonMarker(new L.LatLng(45.43957, 123.17165), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_12._latlng = polygon_12._centerLatLng
# polygon_12.bindPopup(&quot;Name: Barak&quot;);
# map.addLayer(polygon_12)
#
# var polygon_13 = new L.RegularPolygonMarker(new L.LatLng(39.86679, 105.04143), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_13._latlng = polygon_13._centerLatLng
# polygon_13.bindPopup(&quot;Name: Winston&quot;);
# map.addLayer(polygon_13)
#
# var polygon_14 = new L.RegularPolygonMarker(new L.LatLng(38.88275, -77.13999), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_14._latlng = polygon_14._centerLatLng
# polygon_14.bindPopup(&quot;Name: Charlotte&quot;);
# map.addLayer(polygon_14)
#
# var polygon_15 = new L.RegularPolygonMarker(new L.LatLng(40.7069, -73.82973), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_15._latlng = polygon_15._centerLatLng
# polygon_15.bindPopup(&quot;Name: Vishpala&quot;);
# map.addLayer(polygon_15)
#
# var polygon_16 = new L.RegularPolygonMarker(new L.LatLng(40.7079, -74.01342), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_16._latlng = polygon_16._centerLatLng
# polygon_16.bindPopup(&quot;Name: Harvey&quot;);
# map.addLayer(polygon_16)
#
# var polygon_17 = new L.RegularPolygonMarker(new L.LatLng(43.08767, -86.19345), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_17._latlng = polygon_17._centerLatLng
# polygon_17.bindPopup(&quot;Name: Manuel&quot;);
# map.addLayer(polygon_17)
#
# var polygon_18 = new L.RegularPolygonMarker(new L.LatLng(44.83141, -93.46031), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_18._latlng = polygon_18._centerLatLng
# polygon_18.bindPopup(&quot;Name: Antoinette&quot;);
# map.addLayer(polygon_18)
#
# var polygon_19 = new L.RegularPolygonMarker(new L.LatLng(37.36211, -79.21525), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_19._latlng = polygon_19._centerLatLng
# polygon_19.bindPopup(&quot;Name: Suiko&quot;);
# map.addLayer(polygon_19)
#
# var polygon_20 = new L.RegularPolygonMarker(new L.LatLng(40.67014, -73.75141), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_20._latlng =

# %%
cuny_map2 = folium.Map(location=[40.737130, -74.026267], zoom_start=12, 
                        tiles='Stamen Toner')
cuny_map2.lat_lng_popover()
for row in df.iterrows():
    wtg_id = str(row[1]['fakename'])
    lat = row[1]['lat']
    lng = row[1]['lon']
    cuny_map2.polygon_marker(location=[lat, lng], fill_color='#f4bf75', 
                              radius=12, num_sides=6, popup='Name: ' + wtg_id)
cuny_map2.create_map('cuny_map.html')
cuny_map2.render_iframe = True
cuny_map2

# %%
map = cuny_map2
inline_map(map)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <link rel=&quot;stylesheet&quot; href=&quot;http://cdn.leafletjs.com/leaflet-0.5/leaflet.css&quot; />
#    <script src=&quot;http://cdn.leafletjs.com/leaflet-0.5/leaflet.js&quot;></script>
#    <script src=&quot;leaflet-dvf.markers.min.js&quot;></script>
#
#
#
#
#
# <style>
#
# #map {
#   position:absolute;
#   top:0;
#   bottom:0;
#   right:0;
#   left:0;
# }
#
# </style>
# </head>
# <body>
#
#         <div id=&quot;map&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
# <script>
#
#
#
# var map = L.map('map').setView([40.73713, -74.026267], 12);
#
# L.tileLayer('http://{s}.tile.stamen.com/toner/{z}/{x}/{y}.jpg', {
#     maxZoom: 18,
#     attribution: 'Map tiles by <a href=&quot;http://stamen.com&quot;>Stamen Design</a>, under <a href=&quot;http://creativecommons.org/licenses/by/3.0&quot;>CC BY 3.0</a>. Data by <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a>, under <a href=&quot;http://creativecommons.org/licenses/by-sa/3.0&quot;>CC BY SA</a>.'
# }).addTo(map);
#
#
# var polygon_1 = new L.RegularPolygonMarker(new L.LatLng(40.24104, -74.27629), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_1._latlng = polygon_1._centerLatLng
# polygon_1.bindPopup(&quot;Name: Geraldo&quot;);
# map.addLayer(polygon_1)
#
# var polygon_2 = new L.RegularPolygonMarker(new L.LatLng(40.35589, -86.88972), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_2._latlng = polygon_2._centerLatLng
# polygon_2.bindPopup(&quot;Name: Ophelia&quot;);
# map.addLayer(polygon_2)
#
# var polygon_3 = new L.RegularPolygonMarker(new L.LatLng(40.7761, -73.98285), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_3._latlng = polygon_3._centerLatLng
# polygon_3.bindPopup(&quot;Name: Valencia&quot;);
# map.addLayer(polygon_3)
#
# var polygon_4 = new L.RegularPolygonMarker(new L.LatLng(43.04117, -86.19013), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_4._latlng = polygon_4._centerLatLng
# polygon_4.bindPopup(&quot;Name: Cezary&quot;);
# map.addLayer(polygon_4)
#
# var polygon_5 = new L.RegularPolygonMarker(new L.LatLng(40.74946, -73.81941), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_5._latlng = polygon_5._centerLatLng
# polygon_5.bindPopup(&quot;Name: Alphonse&quot;);
# map.addLayer(polygon_5)
#
# var polygon_6 = new L.RegularPolygonMarker(new L.LatLng(38.07655, -78.89839), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_6._latlng = polygon_6._centerLatLng
# polygon_6.bindPopup(&quot;Name: Sabriel&quot;);
# map.addLayer(polygon_6)
#
# var polygon_7 = new L.RegularPolygonMarker(new L.LatLng(38.99976, -77.10185), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_7._latlng = polygon_7._centerLatLng
# polygon_7.bindPopup(&quot;Name: Elizabeth&quot;);
# map.addLayer(polygon_7)
#
# var polygon_8 = new L.RegularPolygonMarker(new L.LatLng(40.71209, -73.95427), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_8._latlng = polygon_8._centerLatLng
# polygon_8.bindPopup(&quot;Name: William&quot;);
# map.addLayer(polygon_8)
#
# var polygon_9 = new L.RegularPolygonMarker(new L.LatLng(40.82892, -74.11064), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_9._latlng = polygon_9._centerLatLng
# polygon_9.bindPopup(&quot;Name: Arnold&quot;);
# map.addLayer(polygon_9)
#
# var polygon_10 = new L.RegularPolygonMarker(new L.LatLng(40.99208, -73.8729), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_10._latlng = polygon_10._centerLatLng
# polygon_10.bindPopup(&quot;Name: Madeline&quot;);
# map.addLayer(polygon_10)
#
# var polygon_11 = new L.RegularPolygonMarker(new L.LatLng(41.29687, -73.78934), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_11._latlng = polygon_11._centerLatLng
# polygon_11.bindPopup(&quot;Name: Hemione&quot;);
# map.addLayer(polygon_11)
#
# var polygon_12 = new L.RegularPolygonMarker(new L.LatLng(45.43957, 123.17165), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_12._latlng = polygon_12._centerLatLng
# polygon_12.bindPopup(&quot;Name: Barak&quot;);
# map.addLayer(polygon_12)
#
# var polygon_13 = new L.RegularPolygonMarker(new L.LatLng(39.86679, 105.04143), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_13._latlng = polygon_13._centerLatLng
# polygon_13.bindPopup(&quot;Name: Winston&quot;);
# map.addLayer(polygon_13)
#
# var polygon_14 = new L.RegularPolygonMarker(new L.LatLng(38.88275, -77.13999), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_14._latlng = polygon_14._centerLatLng
# polygon_14.bindPopup(&quot;Name: Charlotte&quot;);
# map.addLayer(polygon_14)
#
# var polygon_15 = new L.RegularPolygonMarker(new L.LatLng(40.7069, -73.82973), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_15._latlng = polygon_15._centerLatLng
# polygon_15.bindPopup(&quot;Name: Vishpala&quot;);
# map.addLayer(polygon_15)
#
# var polygon_16 = new L.RegularPolygonMarker(new L.LatLng(40.7079, -74.01342), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_16._latlng = polygon_16._centerLatLng
# polygon_16.bindPopup(&quot;Name: Harvey&quot;);
# map.addLayer(polygon_16)
#
# var polygon_17 = new L.RegularPolygonMarker(new L.LatLng(43.08767, -86.19345), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_17._latlng = polygon_17._centerLatLng
# polygon_17.bindPopup(&quot;Name: Manuel&quot;);
# map.addLayer(polygon_17)
#
# var polygon_18 = new L.RegularPolygonMarker(new L.LatLng(44.83141, -93.46031), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_18._latlng = polygon_18._centerLatLng
# polygon_18.bindPopup(&quot;Name: Antoinette&quot;);
# map.addLayer(polygon_18)
#
# var polygon_19 = new L.RegularPolygonMarker(new L.LatLng(37.36211, -79.21525), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_19._latlng = polygon_19._centerLatLng
# polygon_19.bindPopup(&quot;Name: Suiko&quot;);
# map.addLayer(polygon_19)
#
# var polygon_20 = new L.RegularPolygonMarker(new L.LatLng(40.67014, -73.75141), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_20._latlng = po

# %%
cuny_map3 = folium.Map(location=[40.737130, -74.026267], zoom_start=12, 
                        tiles='OpenStreetMap')
cuny_map3.lat_lng_popover()
for row in df.iterrows():
    wtg_id = str(row[1]['fakename'])
    lat = row[1]['lat']
    lng = row[1]['lon']
    cuny_map3.polygon_marker(location=[lat, lng], fill_color='#f4bf75', 
                              radius=12, num_sides=6, popup='Name: ' + wtg_id)
cuny_map3.create_map('cuny_map.html')
cuny_map3.render_iframe = True
cuny_map3

# %%
map = cuny_map3
inline_map(map)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <link rel=&quot;stylesheet&quot; href=&quot;http://cdn.leafletjs.com/leaflet-0.5/leaflet.css&quot; />
#    <script src=&quot;http://cdn.leafletjs.com/leaflet-0.5/leaflet.js&quot;></script>
#    <script src=&quot;leaflet-dvf.markers.min.js&quot;></script>
#
#
#
#
#
# <style>
#
# #map {
#   position:absolute;
#   top:0;
#   bottom:0;
#   right:0;
#   left:0;
# }
#
# </style>
# </head>
# <body>
#
#         <div id=&quot;map&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
# <script>
#
#
#
# var map = L.map('map').setView([40.73713, -74.026267], 12);
#
# L.tileLayer('http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#     maxZoom: 18,
#     attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
# }).addTo(map);
#
#
# var polygon_1 = new L.RegularPolygonMarker(new L.LatLng(40.24104, -74.27629), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_1._latlng = polygon_1._centerLatLng
# polygon_1.bindPopup(&quot;Name: Geraldo&quot;);
# map.addLayer(polygon_1)
#
# var polygon_2 = new L.RegularPolygonMarker(new L.LatLng(40.35589, -86.88972), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_2._latlng = polygon_2._centerLatLng
# polygon_2.bindPopup(&quot;Name: Ophelia&quot;);
# map.addLayer(polygon_2)
#
# var polygon_3 = new L.RegularPolygonMarker(new L.LatLng(40.7761, -73.98285), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_3._latlng = polygon_3._centerLatLng
# polygon_3.bindPopup(&quot;Name: Valencia&quot;);
# map.addLayer(polygon_3)
#
# var polygon_4 = new L.RegularPolygonMarker(new L.LatLng(43.04117, -86.19013), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_4._latlng = polygon_4._centerLatLng
# polygon_4.bindPopup(&quot;Name: Cezary&quot;);
# map.addLayer(polygon_4)
#
# var polygon_5 = new L.RegularPolygonMarker(new L.LatLng(40.74946, -73.81941), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_5._latlng = polygon_5._centerLatLng
# polygon_5.bindPopup(&quot;Name: Alphonse&quot;);
# map.addLayer(polygon_5)
#
# var polygon_6 = new L.RegularPolygonMarker(new L.LatLng(38.07655, -78.89839), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_6._latlng = polygon_6._centerLatLng
# polygon_6.bindPopup(&quot;Name: Sabriel&quot;);
# map.addLayer(polygon_6)
#
# var polygon_7 = new L.RegularPolygonMarker(new L.LatLng(38.99976, -77.10185), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_7._latlng = polygon_7._centerLatLng
# polygon_7.bindPopup(&quot;Name: Elizabeth&quot;);
# map.addLayer(polygon_7)
#
# var polygon_8 = new L.RegularPolygonMarker(new L.LatLng(40.71209, -73.95427), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_8._latlng = polygon_8._centerLatLng
# polygon_8.bindPopup(&quot;Name: William&quot;);
# map.addLayer(polygon_8)
#
# var polygon_9 = new L.RegularPolygonMarker(new L.LatLng(40.82892, -74.11064), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_9._latlng = polygon_9._centerLatLng
# polygon_9.bindPopup(&quot;Name: Arnold&quot;);
# map.addLayer(polygon_9)
#
# var polygon_10 = new L.RegularPolygonMarker(new L.LatLng(40.99208, -73.8729), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_10._latlng = polygon_10._centerLatLng
# polygon_10.bindPopup(&quot;Name: Madeline&quot;);
# map.addLayer(polygon_10)
#
# var polygon_11 = new L.RegularPolygonMarker(new L.LatLng(41.29687, -73.78934), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_11._latlng = polygon_11._centerLatLng
# polygon_11.bindPopup(&quot;Name: Hemione&quot;);
# map.addLayer(polygon_11)
#
# var polygon_12 = new L.RegularPolygonMarker(new L.LatLng(45.43957, 123.17165), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_12._latlng = polygon_12._centerLatLng
# polygon_12.bindPopup(&quot;Name: Barak&quot;);
# map.addLayer(polygon_12)
#
# var polygon_13 = new L.RegularPolygonMarker(new L.LatLng(39.86679, 105.04143), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_13._latlng = polygon_13._centerLatLng
# polygon_13.bindPopup(&quot;Name: Winston&quot;);
# map.addLayer(polygon_13)
#
# var polygon_14 = new L.RegularPolygonMarker(new L.LatLng(38.88275, -77.13999), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_14._latlng = polygon_14._centerLatLng
# polygon_14.bindPopup(&quot;Name: Charlotte&quot;);
# map.addLayer(polygon_14)
#
# var polygon_15 = new L.RegularPolygonMarker(new L.LatLng(40.7069, -73.82973), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_15._latlng = polygon_15._centerLatLng
# polygon_15.bindPopup(&quot;Name: Vishpala&quot;);
# map.addLayer(polygon_15)
#
# var polygon_16 = new L.RegularPolygonMarker(new L.LatLng(40.7079, -74.01342), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_16._latlng = polygon_16._centerLatLng
# polygon_16.bindPopup(&quot;Name: Harvey&quot;);
# map.addLayer(polygon_16)
#
# var polygon_17 = new L.RegularPolygonMarker(new L.LatLng(43.08767, -86.19345), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_17._latlng = polygon_17._centerLatLng
# polygon_17.bindPopup(&quot;Name: Manuel&quot;);
# map.addLayer(polygon_17)
#
# var polygon_18 = new L.RegularPolygonMarker(new L.LatLng(44.83141, -93.46031), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_18._latlng = polygon_18._centerLatLng
# polygon_18.bindPopup(&quot;Name: Antoinette&quot;);
# map.addLayer(polygon_18)
#
# var polygon_19 = new L.RegularPolygonMarker(new L.LatLng(37.36211, -79.21525), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_19._latlng = polygon_19._centerLatLng
# polygon_19.bindPopup(&quot;Name: Suiko&quot;);
# map.addLayer(polygon_19)
#
# var polygon_20 = new L.RegularPolygonMarker(new L.LatLng(40.67014, -73.75141), {
#     color: 'black',
#     opacity: 1,
#     weight: 2,
#     fillColor: '#f4bf75',
#     fillOpacity: 1,
#     numberOfSides: 6,
#     rotation: 0,
#     radius: 12
# });
# polygon_20._latlng = polygon_20._centerLatLng
# polygon_20.bindPopup(&quot;Name: Federico&quot;);
# map.addLayer(polygon_20)
#
# var polygon_21 = new L.RegularPolygonMarker(new L.LatLng(37.65778, -121.73011), {
#     color: 'black',
#     opacity: 1,
#     w
